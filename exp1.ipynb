# %% [markdown]
# exp 1: Introduction to Python

# %%
# Prince Kumar Sharma, PRN:25070123086

# %%
x,y,z = "Apple","Orange","Cherry"
print(x,y,z,sep="\n")
# Out:
# Apple
# Orange
# Cherry

# %%
x,y,z,w = 2,2.5,"Prince", True
print(type(x),type(y),type(z),type(w),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a,b = 10,5
print("Sum =",a+b,"\nSub =",a-b,"\nMult = ",a*b,"\ndiv = ",a/b,"\nexp =",a**b)
# Out:
# Sum = 15
# Sub = 5
# Mult =  50
# div =  2.0
# exp = 100000

# %%
a = int(input("Enter Integer a: "))
b = int(input("Enter Integer b: "))
print("Sum =",a+b,"\nSub =",a-b,"\nMult = ",a*b,"\ndiv = ",a/b,"\nexp =",a**b)
# Out:
# Enter Integer a: 55
# Enter Integer b: 5
# Sum = 60
# Sub = 50
# Mult =  275
# div =  11.0
# exp = 503284375

# %%
import math
r = float(input("Enter radius of circle: "))
print("Area of circle is ", math.pi*(r**2))
# Out:
# Enter radius of circle: 1
# Area of circle is  3.141592653589793

# %%
import math
print("Value of log 10 with base 10: ",math.log10(10))
print("Value of Sin60: ", math.sin(math.pi/3))
# Out:
# Value of log 10 with base 10:  1.0
# Value of Sin60:  0.8660254037844386

# %%
a = int(input("Enter Integer a: "))
b = int(input("Enter Integer b: "))
if a>b:
  print("a is greater than b")
elif a<b:
  print("b is greater than a")
else:
  print("a and b are equal")
# Out:
# Enter Integer a: 5
# Enter Integer b: 5
# a and b are equal
